# %% [markdown]
# # Run Prototype-based FL on Colab
# This notebook clones your GitHub repository, sets the hardware to `cuda`, and runs the FPL framework using your A100/T4 GPU.

# %%
# 1. Clone the repository
# !git clone https://github.com/ekinkyl/prototype_based_fl
# %cd prototype_based_fl
# Out:
# Cloning into 'prototype_based_fl'...
# remote: Enumerating objects: 406, done.
# remote: Counting objects: 100% (406/406), done.
# remote: Compressing objects: 100% (299/299), done.
# remote: Total 406 (delta 172), reused 304 (delta 88), pack-reused 0 (from 0)
# Receiving objects: 100% (406/406), 31.20 MiB | 16.43 MiB/s, done.
# Resolving deltas: 100% (172/172), done.
# Updating files: 100% (203/203), done.
# /content/prototype_based_fl

# %%
# 2. Modify the central_config.yaml to use 'cuda' instead of 'cpu'
import yaml

with open('central_config.yaml', 'r') as f:
    config = yaml.safe_load(f)

config['runtime']['device'] = 'cuda'

with open('central_config.yaml', 'w') as f:
    yaml.dump(config, f)

print("Config updated to use CUDA!")
# Out:
# Config updated to use CUDA!

# %%
# !git pull origin main
# !python main_runner.py --framework FedTGP --install-deps
# Out:
# From https://github.com/ekinkyl/prototype_based_fl
#  * branch            main       -> FETCH_HEAD
# Already up to date.
# 2026-07-05 21:58:23,720 | INFO | Experiment: mnist_prototype_fl_benchmark
# 2026-07-05 21:58:23,720 | INFO | Config: /content/prototype_based_fl/central_config.yaml
# 2026-07-05 21:58:23,720 | INFO | Frameworks: FedTGP
# 2026-07-05 21:58:23,720 | INFO | [FedTGP] Installing dependencies from /content/prototype_based_fl/frameworks/FedTGP/requirements.txt ...
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from -r /content/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (2.11.0+cu128)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from -r /content/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 2)) (0.26.0+cu128)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r /content/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 3)) (2.0.2)
# Collecting calmsize (from -r /content/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 4))
#   Downloading calmsize-0.1.3.tar.gz (3.7 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from -r /content/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 5)) (3.16.0)
# Collecting ujson (from -r /content/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 6))
#   Downloading ujson-5.13.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (10.0 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from -r /content/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 7)) (1.6.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (3.29.4)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision->-r /content/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 2)) (11.3.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r /content/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 7)) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r /content/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 7)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r /content/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 7)) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch->-r /content/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (1.5.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->-r /content/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->-r /content/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (3.0.3)
# Downloading ujson-5.13.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 3.2 MB/s eta 0:00:00
# Building wheels for collected packages: calmsize
#   Building wheel for calmsize (setup.py) ... done
#   Created wheel for calmsize: filename=calmsize-0.1.3-py3-none-any.whl size=2873 sha256=a05fc14eeed3147ca769e536add805ddbd14fa40fe3eaea6aed9996909000a2c
#   Stored in directory: /root/.cache/pip/wheels/12/94/f3/cf4d9ae355a5cd03a392f3c8b55cbe325e9150fd61ac289b56
# Successfully built calmsize
# Installing collected packages: ujson, calmsize
# Successfully installed calmsize-0.1.3 ujson-5.13.0
# 2026-07-05 21:58:29,113 | INFO | [FedTGP] Dependencies installed successfully.
# 2026-07-05 21:58:29,114 | INFO | [FedTGP] Running data generation script...
# Generating MNIST: niid=True, balance=False, partition=dir, alpha=0.1, num_clients=20
# 100% 9.91M/9.91M [00:00<00:00, 18.4MB/s]
# 100% 28.9k/28.9k [00:00<00:00, 496kB/s]
# 100% 1.65M/1.65M [00:00<00:00, 4.70MB/s]
# 100% 4.54k/4.54k [00:00<00:00, 24.2MB/s]
# Saved 20 clients to mnist/train/ and mnist/test/
# MNIST dataset generation complete.
# 2026-07-05 21:58:51,099 | INFO | --- Running FedTGP ---
# 2026-07-05 21:58:51,099 | INFO | CWD: /content/prototype_based_fl/frameworks/FedTGP/system
# 2026-07-05 21:58:51,100 | INFO | CMD: /usr/bin/python3 /content/prototype_based_fl/frameworks/FedTGP/system/main.py -data mnist -m HtFE3_MNIST -algo FedTGP -go test -nc 10 -gr 20 -ls 10 -lbs 64 -lr 0.01
# 2026-07-05 21:58:51,100 | INFO | ENV (benchmark): DATA_ROOT=/content/prototype_based_fl/shared_datasets
# ==================================================
# Algorithm: FedTGP
# Local batch size: 64
# Local steps: 10
# Local learing rate: 0.01
# Total number of clients: 10
# Clients join in each round: 1.0
# Clients randomly join: False
# Client drop rate: 0.0
# Client select regarding time: False
# Running times: 1
# Dataset: mnist
# Number of classes: 10
# Backbone: HtFE3_MNIST
# Using device: cuda
# Auto break: False
# Global rounds: 20
# ==================================================
#
# ============= Running time: 0th =============
# Creating server and clients ...
# resnet10(in_channels=1, num_classes=args.num_classes)
# resnet18(in_channels=1, num_classes=args.num_classes)
# resnet34(in_channels=1, num_classes=args.num_classes)
#
# Join ratio / total clients: 1.0 / 10
# Finished creating server and clients.
# Trainable_Global_Prototypes(
#   (embedings): Embedding(10, 512)
#   (middle): Sequential(
#     (0): Sequential(
#       (0): Linear(in_features=512, out_features=512, bias=True)
#       (1): ReLU()
#     )
#   )
#   (fc): Linear(in_features=512, out_features=512, bias=True)
# )
#
# -------------Round number: 0-------------
#
# Evaluate heterogeneous models
# Server global_protos Not Found
# Client 0: Acc: 0.0, AUC: 0
# Server global_protos Not Found
# Client 1: Acc: 0.0, AUC: 0
# Server global_protos Not Found
# Client 2: Acc: 0.0, AUC: 0
# Server global_protos Not Found
# Client 3: Acc: 0.0, AUC: 0
# Server global_protos Not Found
# Client 4: Acc: 0.0, AUC: 0
# Server global_protos Not Found
# Client 5: Acc: 0.0, AUC: 0
# Server global_protos Not Found
# Client 6: Acc: 0.0, AUC: 0
# Server global_protos Not Found
# Client 7: Acc: 0.0, AUC: 0
# Server global_protos Not Found
# Client 8: Acc: 0.0, AUC: 0
# Server global_protos Not Found
# Client 9: Acc: 0.0, AUC: 0
# Averaged Test Accurancy: 0.0000
# Averaged Test AUC: 0.0000
# Std Test Accurancy: 0.0000
# Std Test AUC: 0.0000
# Server global_protos Not Found
# Server global_protos Not Found
# Server global_protos Not Found
# Server global_protos Not Found
# Server global_protos Not Found
# Server global_protos Not Found
# Server global_protos Not Found
# Server global_protos Not Found
# Server global_protos Not Found
# Server global_protos Not Found
# class-wise minimum distance tensor([ 4.3225,  7.1755,  1.2080, 13.0350,  9.3330,  1.3388,  7.4744,  1.2080,
#          4.3225,  7.1755], device='cuda:0')
# min_gap tensor(1.2080, device='cuda:0')
# max_gap tensor(13.0350, device='cuda:0')
# Server loss: 15.00864028930664
# -------------------------------------------------- 176.35039114952087
#
# -------------Round number: 1-------------
#
# Evaluate heterogeneous models
# Client 0: Acc: 0.2553191489361702, AUC: 0
# Client 1: Acc: 0.0, AUC: 0
# Client 2: Acc: 0.014705882352941176, AUC: 0
# Client 3: Acc: 0.007861635220125786, AUC: 0
# Client 4: Acc: 0.027083333333333334, AUC: 0
# Client 5: Acc: 0.10400516795865633, AUC: 0
# Client 6: Acc: 0.6273885350318471, AUC: 0
# Client 7: Acc: 0.012578616352201259, AUC: 0
# Client 8: Acc: 0.8411111111111111, AUC: 0
# Client 9: Acc: 0.37924151696606784, AUC: 0
# Averaged Test Accurancy: 0.2647
# Averaged Test AUC: 0.0000
# Std Test Accurancy: 0.2841
# Std Test AUC: 0.0000
# class-wise minimum distance tensor([2.8101, 3.1036, 2.8620, 3.5783, 3.2936, 3.5346, 2.5045, 3.1036, 2.5045,
#         2.9710], device='cuda:0')
# min_gap tensor(2.5045, device='cuda:0')
# max_gap tensor(3.5783, device='cuda:0')
# Server loss: 3.573462724685669
# -------------------------------------------------- 184.83558893203735
#
# -------------Round number: 2-------------
#
# Evaluate heterogeneous models
# Client 0: Acc: 0.7386018237082067, AUC: 0
# Client 1: Acc: 0.632, AUC: 0
# Client 2: Acc: 0.46078431372549017, AUC: 0
# Client 3: Acc: 0.5959119496855346, AUC: 0
# Client 4: Acc: 0.8645833333333334, AUC: 0
# Client 5: Acc: 0.014211886304909561, AUC: 0
# Client 6: Acc: 0.8980891719745223, AUC: 0
# Client 7: Acc: 0.9433962264150944, AUC: 0
# Client 8: Acc: 0.6522222222222223, AUC: 0
# Client 9: Acc: 0.9640718562874252, AUC: 0
# Averaged Test Accurancy: 0.5797
# Averaged Test AUC: 0.0000
# Std Test Accurancy: 0.2714
# Std Test AUC: 0.0000
# class-wise minimum distance tensor([3.1899, 2.5608, 3.0780, 3.4259, 3.5459, 3.6424, 3.1788, 2.5608, 3.0780,
#         3.3285], device='cuda:0')
# min_gap tensor(2.5608, device='cuda:0')
# max_gap tensor(3.6424, device='cuda:0')
# Server loss: 3.2641327381134033
# -------------------------------------------------- 185.28510665893555
#
# -------------Round number: 3-------------
#
# Evaluate heterogeneous models
# Client 0: Acc: 0.9285714285714286, AUC: 0
# Client 1: Acc: 0.784, AUC: 0
# Client 2: Acc: 0.9558823529411765, AUC: 0
# Client 3: Acc: 0.9213836477987422, AUC: 0
# Client 4: Acc: 0.9166666666666666, AUC: 0
# Client 5: Acc: 0.9870801033591732, AUC: 0
# Client 6: Acc: 0.9299363057324841, AUC: 0
# Client 7: Acc: 0.9622641509433962, AUC: 0
# Client 8: Acc: 0.9988888888888889, AUC: 0
# Client 9: Acc: 0.9750499001996008, AUC: 0
# Averaged Test Accurancy: 0.9590
# Averaged Test AUC: 0.0000
# Std Test Accurancy: 0.0574
# Std Test AUC: 0.0000
# class-wise minimum distance tensor([4.7278, 4.7343, 4.6682, 5.6377, 4.3669, 5.7690, 4.6682, 4.3669, 4.9511,
#         5.8521], device='cuda:0')
# min_gap tensor(4.3669, device='cuda:0')
# max_gap tensor(5.8521, device='cuda:0')
# Server loss: 3.887479305267334
# -------------------------------------------------- 185.61386919021606
#
# -------------Round number: 4-------------
#
# Evaluate heterogeneous models
# Client 0: Acc: 0.9513677811550152, AUC: 0
# Client 1: Acc: 0.816, AUC: 0
# Client 2: Acc: 0.9730392156862745, AUC: 0
# Client 3: Acc: 0.9905660377358491, AUC: 0
# Client 4: Acc: 0.9333333333333333, AUC: 0
# Client 5: Acc: 0.9870801033591732, AUC: 0
# Client 6: Acc: 0.9426751592356688, AUC: 0
# Client 7: Acc: 0.9622641509433962, AUC: 0
# Client 8: Acc: 0.9988888888888889, AUC: 0
# Client 9: Acc: 0.9750499001996008, AUC: 0
# Averaged Test Accurancy: 0.9718
# Averaged Test AUC: 0.0000
# Std Test Accurancy: 0.0499
# Std Test AUC: 0.0000
# class-wise minimum distance tensor([5.6392, 5.5180, 5.6392, 6.9477, 4.9401, 6.9617, 5.8605, 4.9401, 5.9344,
#         6.9585], device='cuda:0')
# min_gap tensor(4.9401, device='cuda:0')
# max_gap tensor(6.9617, device='cuda:0')
# Server loss: 4.10111665725708
# -------------------------------------------------- 183.8482527732849
#
# -------------Round number: 5-------------
#
# Evaluate heterogeneous models
# Client 0: Acc: 0.9544072948328267, AUC: 0
# Client 1: Acc: 0.832, AUC: 0
# Client 2: Acc: 0.9852941176470589, AUC: 0
# Client 3: Acc: 0.9905660377358491, AUC: 0
# Client 4: Acc: 0.9375, AUC: 0
# Client 5: Acc: 0.9877260981912145, AUC: 0
# Client 6: Acc: 0.9394904458598726, AUC: 0
# Client 7: Acc: 0.9622641509433962, AUC: 0
# Client 8: Acc: 0.9988888888888889, AUC: 0
# Client 9: Acc: 0.9760479041916168, AUC: 0
# Averaged Test Accurancy: 0.9737
# Averaged Test AUC: 0.0000
# Std Test Accurancy: 0.0462
# Std Test AUC: 0.0000
# class-wise minimum distance tensor([6.4430, 6.6864, 6.4430, 8.2943, 5.5194, 7.9959, 6.9557, 5.5194, 6.8424,
#         8.1220], device='cuda:0')
# min_gap tensor(5.5194, device='cuda:0')
# max_gap tensor(8.2943, device='cuda:0')
# Server loss: 4.582203388214111
# -------------------------------------------------- 184.71026372909546
#
# -------------Round number: 6-------------
#
# Evaluate heterogeneous models
# Client 0: Acc: 0.952887537993921, AUC: 0
# Client 1: Acc: 0.84, AUC: 0
# Client 2: Acc: 0.9877450980392157, AUC: 0
# Client 3: Acc: 0.9905660377358491, AUC: 0
# Client 4: Acc: 0.9416666666666667, AUC: 0
# Client 5: Acc: 0.9916020671834626, AUC: 0
# Client 6: Acc: 0.9394904458598726, AUC: 0
# Client 7: Acc: 0.9654088050314465, AUC: 0
# Client 8: Acc: 0.9988888888888889, AUC: 0
# Client 9: Acc: 0.9750499001996008, AUC: 0
# Averaged Test Accurancy: 0.9751
# Averaged Test AUC: 0.0000
# Std Test Accurancy: 0.0443
# Std Test AUC: 0.0000
# class-wise minimum distance tensor([7.2672, 7.5504, 7.2672, 8.9489, 6.0587, 8.8166, 7.8842, 6.0587, 7.4453,
#         9.0484], device='cuda:0')
# min_gap tensor(6.0587, device='cuda:0')
# max_gap tensor(9.0484, device='cuda:0')
# Server loss: 4.673159599304199
# -------------------------------------------------- 184.43169903755188
#
# -------------Round number: 7-------------
#
# Evaluate heterogeneous models
# Client 0: Acc: 0.9513677811550152, AUC: 0
# Client 1: Acc: 0.848, AUC: 0
# Client 2: Acc: 0.9926470588235294, AUC: 0
# Client 3: Acc: 0.9968553459119497, AUC: 0
# Client 4: Acc: 0.95, AUC: 0
# Client 5: Acc: 0.9922480620155039, AUC: 0
# Client 6: Acc: 0.9394904458598726, AUC: 0
# Client 7: Acc: 0.9654088050314465, AUC: 0
# Client 8: Acc: 0.9988888888888889, AUC: 0
# Client 9: Acc: 0.9760479041916168, AUC: 0
# Averaged Test Accurancy: 0.9770
# Averaged Test AUC: 0.0000
# Std Test Accurancy: 0.0429
# Std Test AUC: 0.0000
# class-wise minimum distance tensor([ 8.0640,  8.3060,  8.0113,  9.4225,  6.5333,  9.5444,  8.6665,  6.5333,
#          8.0113, 10.0037], device='cuda:0')
# min_gap tensor(6.5333, device='cuda:0')
# max_gap tensor(10.0037, device='cuda:0')
# Server loss: 4.975825309753418
# -------------------------------------------------- 184.60064578056335
#
# -------------Round number: 8-------------
#
# Evaluate heterogeneous models
# Client 0: Acc: 0.9544072948328267, AUC: 0
# Client 1: Acc: 0.856, AUC: 0
# Client 2: Acc: 0.9926470588235294, AUC: 0
# Client 3: Acc: 0.9984276729559748, AUC: 0
# Client 4: Acc: 0.9520833333333333, AUC: 0
# Client 5: Acc: 0.9935400516795866, AUC: 0
# Client 6: Acc: 0.9394904458598726, AUC: 0
# Client 7: Acc: 0.9685534591194969, AUC: 0
# Client 8: Acc: 0.9988888888888889, AUC: 0
# Client 9: Acc: 0.9770459081836327, AUC: 0
# Averaged Test Accurancy: 0.9784
# Averaged Test AUC: 0.0000
# Std Test Accurancy: 0.0410
# Std Test AUC: 0.0000
# class-wise minimum distance tensor([ 8.8376,  8.9073,  8.5247,  9.7428,  6.9702, 10.1679,  9.3005,  6.9702,
#          8.5247, 10.8531], device='cuda:0')
# min_gap tensor(6.9702, device='cuda:0')
# max_gap tensor(10.8531, device='cuda:0')
# Server loss: 5.21954870223999
# -------------------------------------------------- 185.6011347770691
#
# -------------Round number: 9-------------
#
# Evaluate heterogeneous models
# Client 0: Acc: 0.9574468085106383, AUC: 0
# Client 1: Acc: 0.856, AUC: 0
# Client 2: Acc: 0.9926470588235294, AUC: 0
# Client 3: Acc: 0.9984276729559748, AUC: 0
# Client 4: Acc: 0.95625, AUC: 0
# Client 5: Acc: 0.9935400516795866, AUC: 0
# Client 6: Acc: 0.9363057324840764, AUC: 0
# Client 7: Acc: 0.9685534591194969, AUC: 0
# Client 8: Acc: 0.9988888888888889, AUC: 0
# Client 9: Acc: 0.9780439121756487, AUC: 0
# Averaged Test Accurancy: 0.9790
# Averaged Test AUC: 0.0000
# Std Test Accurancy: 0.0410
# Std Test AUC: 0.0000
# class-wise minimum distance tensor([ 9.5677,  9.4114,  8.9990, 10.0539,  7.3325, 10.7505,  9.8581,  7.3325,
#          8.9990, 11.6844], device='cuda:0')
# min_gap tensor(7.3325, device='cuda:0')
# max_gap tensor(11.6844, device='cuda:0')
# Server loss: 5.47930908203125
# -------------------------------------------------- 184.61100554466248
#
# -------------Round number: 10-------------
#
# Evaluate heterogeneous models
# Client 0: Acc: 0.9650455927051672, AUC: 0
# Client 1: Acc: 0.864, AUC: 0
# Client 2: Acc: 0.9926470588235294, AUC: 0
# Client 3: Acc: 0.9984276729559748, AUC: 0
# Client 4: Acc: 0.9583333333333334, AUC: 0
# Client 5: Acc: 0.9935400516795866, AUC: 0
# Client 6: Acc: 0.9394904458598726, AUC: 0
# Client 7: Acc: 0.9716981132075472, AUC: 0
# Client 8: Acc: 0.9988888888888889, AUC: 0
# Client 9: Acc: 0.9800399201596807, AUC: 0
# Averaged Test Accurancy: 0.9807
# Averaged Test AUC: 0.0000
# Std Test Accurancy: 0.0387
# Std Test AUC: 0.0000
# class-wise minimum distance tensor([10.2852,  9.8534,  9.4764, 10.3741,  7.6930, 11.2696, 10.3674,  7.6930,
#          9.4764, 12.2247], device='cuda:0')
# min_gap tensor(7.6930, device='cuda:0')
# max_gap tensor(12.2247, device='cuda:0')
# Server loss: 5.522609233856201
# -------------------------------------------------- 184.3694713115692
#
# -------------Round number: 11-------------
#
# Evaluate heterogeneous models
# Client 0: Acc: 0.9665653495440729, AUC: 0
# Client 1: Acc: 0.856, AUC: 0
# Client 2: Acc: 0.9950980392156863, AUC: 0
# Client 3: Acc: 0.9984276729559748, AUC: 0
# Client 4: Acc: 0.9583333333333334, AUC: 0
# Client 5: Acc: 0.9935400516795866, AUC: 0
# Client 6: Acc: 0.9394904458598726, AUC: 0
# Client 7: Acc: 0.9716981132075472, AUC: 0
# Client 8: Acc: 0.9988888888888889, AUC: 0
# Client 9: Acc: 0.9820359281437125, AUC: 0
# Averaged Test Accurancy: 0.9812
# Averaged Test AUC: 0.0000
# Std Test Accurancy: 0.0411
# Std Test AUC: 0.0000
# class-wise minimum distance tensor([10.9349, 10.2349,  9.9020, 10.6963,  8.0074, 11.7406, 10.8187,  8.0074,
#          9.9020, 12.7417], device='cuda:0')
# min_gap tensor(8.0074, device='cuda:0')
# max_gap tensor(12.7417, device='cuda:0')
# Server loss: 5.583669185638428
# -------------------------------------------------- 184.2201051712036
#
# -------------Round number: 12-------------
#
# Evaluate heterogeneous models
# Client 0: Acc: 0.9711246200607903, AUC: 0
# Client 1: Acc: 0.856, AUC: 0
# Client 2: Acc: 0.9950980392156863, AUC: 0
# Client 3: Acc: 0.9984276729559748, AUC: 0
# Client 4: Acc: 0.9604166666666667, AUC: 0
# Client 5: Acc: 0.9935400516795866, AUC: 0
# Client 6: Acc: 0.9426751592356688, AUC: 0
# Client 7: Acc: 0.9716981132075472, AUC: 0
# Client 8: Acc: 0.9988888888888889, AUC: 0
# Client 9: Acc: 0.9820359281437125, AUC: 0
# Averaged Test Accurancy: 0.9820
# Averaged Test AUC: 0.0000
# Std Test Accurancy: 0.0409
# Std Test AUC: 0.0000
# class-wise minimum distance tensor([11.5513, 10.5962, 10.3417, 11.0337,  8.2935, 12.2061, 11.2574,  8.2935,
#         10.3417, 13.2489], device='cuda:0')
# min_gap tensor(8.2935, device='cuda:0')
# max_gap tensor(13.2489, device='cuda:0')
# Server loss: 5.639383316040039
# -------------------------------------------------- 184.1543300151825
#
# -------------Round number: 13-------------
#
# Evaluate heterogeneous models
# Client 0: Acc: 0.9696048632218845, AUC: 0
# Client 1: Acc: 0.856, AUC: 0
# Client 2: Acc: 0.9950980392156863, AUC: 0
# Client 3: Acc: 0.9984276729559748, AUC: 0
# Client 4: Acc: 0.9604166666666667, AUC: 0
# Client 5: Acc: 0.9928940568475452, AUC: 0
# Client 6: Acc: 0.9426751592356688, AUC: 0
# Client 7: Acc: 0.9716981132075472, AUC: 0
# Client 8: Acc: 0.9988888888888889, AUC: 0
# Client 9: Acc: 0.9830339321357285, AUC: 0
# Averaged Test Accurancy: 0.9818
# Averaged Test AUC: 0.0000
# Std Test Accurancy: 0.0409
# Std Test AUC: 0.0000
# class-wise minimum distance tensor([12.1364, 10.9396, 10.6397, 11.3926,  8.5563, 12.6443, 11.6844,  8.5563,
#         10.7795, 13.8011], device='cuda:0')
# min_gap tensor(8.5563, device='cuda:0')
# max_gap tensor(13.8011, device='cuda:0')
# Server loss: 5.735748291015625
# -------------------------------------------------- 184.05378985404968
#
# -------------Round number: 14-------------
#
# Evaluate heterogeneous models
# Client 0: Acc: 0.9726443768996961, AUC: 0
# Client 1: Acc: 0.872, AUC: 0
# Client 2: Acc: 0.9950980392156863, AUC: 0
# Client 3: Acc: 0.9984276729559748, AUC: 0
# Client 4: Acc: 0.9625, AUC: 0
# Client 5: Acc: 0.9935400516795866, AUC: 0
# Client 6: Acc: 0.9426751592356688, AUC: 0
# Client 7: Acc: 0.9716981132075472, AUC: 0
# Client 8: Acc: 0.9988888888888889, AUC: 0
# Client 9: Acc: 0.9840319361277445, AUC: 0
# Averaged Test Accurancy: 0.9829
# Averaged Test AUC: 0.0000
# Std Test Accurancy: 0.0367
# Std Test AUC: 0.0000
# class-wise minimum distance tensor([12.6972, 11.2804, 10.9101, 11.7847,  8.8232, 13.0564, 12.1124,  8.8232,
#         11.2621, 14.3649], device='cuda:0')
# min_gap tensor(8.8232, device='cuda:0')
# max_gap tensor(14.3649, device='cuda:0')
# Server loss: 5.833946228027344
# -------------------------------------------------- 184.79340314865112
#
# -------------Round number: 15-------------
#
# Evaluate heterogeneous models
# Client 0: Acc: 0.9726443768996961, AUC: 0
# Client 1: Acc: 0.888, AUC: 0
# Client 2: Acc: 0.9950980392156863, AUC: 0
# Client 3: Acc: 0.9984276729559748, AUC: 0
# Client 4: Acc: 0.9604166666666667, AUC: 0
# Client 5: Acc: 0.9935400516795866, AUC: 0
# Client 6: Acc: 0.9426751592356688, AUC: 0
# Client 7: Acc: 0.9716981132075472, AUC: 0
# Client 8: Acc: 0.9988888888888889, AUC: 0
# Client 9: Acc: 0.9840319361277445, AUC: 0
# Averaged Test Accurancy: 0.9831
# Averaged Test AUC: 0.0000
# Std Test Accurancy: 0.0325
# Std Test AUC: 0.0000
# class-wise minimum distance tensor([13.2455, 11.6074, 11.2063, 12.2158,  9.1033, 13.4566, 12.5487,  9.1033,
#         11.7946, 14.9579], device='cuda:0')
# min_gap tensor(9.1033, device='cuda:0')
# max_gap tensor(14.9579, device='cuda:0')
# Server loss: 5.943647861480713
# -------------------------------------------------- 184.31972670555115
#
# -------------Round number: 16-------------
#
# Evaluate heterogeneous models
# Client 0: Acc: 0.9726443768996961, AUC: 0
# Client 1: Acc: 0.888, AUC: 0
# Client 2: Acc: 0.9950980392156863, AUC: 0
# Client 3: Acc: 0.9984276729559748, AUC: 0
# Client 4: Acc: 0.9625, AUC: 0
# Client 5: Acc: 0.9935400516795866, AUC: 0
# Client 6: Acc: 0.9426751592356688, AUC: 0
# Client 7: Acc: 0.9716981132075472, AUC: 0
# Client 8: Acc: 0.9988888888888889, AUC: 0
# Client 9: Acc: 0.9860279441117764, AUC: 0
# Averaged Test Accurancy: 0.9836
# Averaged Test AUC: 0.0000
# Std Test Accurancy: 0.0326
# Std Test AUC: 0.0000
# class-wise minimum distance tensor([13.7632, 11.9192, 11.5023, 12.6979,  9.3693, 13.8582, 12.9848,  9.3693,
#         12.3249, 15.5322], device='cuda:0')
# min_gap tensor(9.3693, device='cuda:0')
# max_gap tensor(15.5322, device='cuda:0')
# Server loss: 6.055798053741455
# -------------------------------------------------- 184.90676021575928
#
# -------------Round number: 17-------------
#
# Evaluate heterogeneous models
# Client 0: Acc: 0.9726443768996961, AUC: 0
# Client 1: Acc: 0.88, AUC: 0
# Client 2: Acc: 0.9950980392156863, AUC: 0
# Client 3: Acc: 0.9984276729559748, AUC: 0
# Client 4: Acc: 0.9625, AUC: 0
# Client 5: Acc: 0.9935400516795866, AUC: 0
# Client 6: Acc: 0.9426751592356688, AUC: 0
# Client 7: Acc: 0.9716981132075472, AUC: 0
# Client 8: Acc: 0.9988888888888889, AUC: 0
# Client 9: Acc: 0.9870259481037924, AUC: 0
# Averaged Test Accurancy: 0.9836
# Averaged Test AUC: 0.0000
# Std Test Accurancy: 0.0347
# Std Test AUC: 0.0000
# class-wise minimum distance tensor([14.2796, 12.2261, 11.8223, 13.0135,  9.6315, 14.2670, 13.4342,  9.6315,
#         12.8861, 16.0901], device='cuda:0')
# min_gap tensor(9.6315, device='cuda:0')
# max_gap tensor(16.0901, device='cuda:0')
# Server loss: 6.159590244293213
# -------------------------------------------------- 184.6275510787964
#
# -------------Round number: 18-------------
#
# Evaluate heterogeneous models
# Client 0: Acc: 0.9741641337386018, AUC: 0
# Client 1: Acc: 0.888, AUC: 0
# Client 2: Acc: 0.9950980392156863, AUC: 0
# Client 3: Acc: 0.9984276729559748, AUC: 0
# Client 4: Acc: 0.9625, AUC: 0
# Client 5: Acc: 0.9922480620155039, AUC: 0
# Client 6: Acc: 0.945859872611465, AUC: 0
# Client 7: Acc: 0.9685534591194969, AUC: 0
# Client 8: Acc: 0.9988888888888889, AUC: 0
# Client 9: Acc: 0.9870259481037924, AUC: 0
# Averaged Test Accurancy: 0.9836
# Averaged Test AUC: 0.0000
# Std Test Accurancy: 0.0323
# Std Test AUC: 0.0000
# Traceback (most recent call last):
#   File "/content/prototype_based_fl/frameworks/FedTGP/system/main.py", line 261, in <module>
#     run(args)
#   File "/content/prototype_based_fl/frameworks/FedTGP/system/main.py", line 145, in run
#     server.train()
#   File "/content/prototype_based_fl/frameworks/FedTGP/system/flcore/servers/servertgp.py", line 64, in train
#     client.train()
#   File "/content/prototype_based_fl/frameworks/FedTGP/system/flcore/clients/clienttgp.py", line 42, in train
#     rep = model.base(x)
#           ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1779, in _wrapped_call_impl
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/subprocess.py", line 1264, in wait
#     return self._wait(timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/subprocess.py", line 2053, in _wait
#     (pid, sts) = self._try_wait(0)
#                  ^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/subprocess.py", line 2011, in _try_wait
#     (pid, sts) = os.waitpid(self.pid, wait_flags)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/prototype_based_fl/main_runner.py", line 806, in <module>
#     raise SystemExit(main())
#                      ^^^^^^
#   File "/content/prototype_based_fl/main_runner.py", line 797, in main
#     return run_benchmark(
#            ^^^^^^^^^^^^^^
#   File "/content/prototype_based_fl/main_runner.py", line 730, in run_benchmark
#     code = run_subprocess(
#            ^^^^^^^^^^^^^^^
#   File "/content/prototype_based_fl/main_runner.py", line 635, in run_subprocess
#     completed = subprocess.run(
#                 ^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/subprocess.py", line 550, in run
#     stdout, stderr = process.communicate(input, timeout=timeout)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/subprocess.py", line 1201, in communicate
#     self.wait()
#   File "/usr/lib/python3.12/subprocess.py", line 1277, in wait
#     self._wait(timeout=sigint_timeout)
#   File "/usr/lib/python3.12/subprocess.py", line 2047, in _wait
#     time.sleep(delay)
# KeyboardInterrupt
# ^C
