# %% [markdown]
# # Run Prototype-based FL on Colab
# This notebook clones your GitHub repository, sets the hardware to `cuda`, and runs the FPL framework using your A100/T4 GPU.

# %%
# 1. Clone the repository
# !git clone https://github.com/ekinkyl/prototype_based_fl
# %cd prototype_based_fl
# Out:
# Cloning into 'prototype_based_fl'...
# remote: Enumerating objects: 132, done.
# remote: Counting objects: 100% (132/132), done.
# remote: Compressing objects: 100% (88/88), done.
# remote: Total 132 (delta 42), reused 119 (delta 37), pack-reused 0 (from 0)
# Receiving objects: 100% (132/132), 277.74 KiB | 25.25 MiB/s, done.
# Resolving deltas: 100% (42/42), done.
# /content/prototype_based_fl

# %%
# 2. Modify the central_config.yaml to use 'cuda' instead of 'cpu'
import yaml

with open('central_config.yaml', 'r') as f:
    config = yaml.safe_load(f)

config['runtime']['device'] = 'cuda'

with open('central_config.yaml', 'w') as f:
    yaml.dump(config, f)

print("Config updated to use CUDA!")
# Out:
# Config updated to use CUDA!

# %%
# 3. Run the orchestrator for FPL (this auto-installs requirements first)
# !python main_runner.py --framework FPL --install-deps
# Out:
# 2026-06-29 20:39:22,086 | INFO | Experiment: mnist_fpl_baseline
# 2026-06-29 20:39:22,087 | INFO | Config: /content/prototype_based_fl/central_config.yaml
# 2026-06-29 20:39:22,087 | INFO | Frameworks: FPL
# 2026-06-29 20:39:22,087 | INFO | [FPL] Installing dependencies from /content/prototype_based_fl/frameworks/FPL/requirements.txt ...
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/prototype_based_fl/frameworks/FPL/requirements.txt (line 5)) (2.11.0+cu128)
# Requirement already satisfied: torchvision>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/prototype_based_fl/frameworks/FPL/requirements.txt (line 6)) (0.26.0+cu128)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/prototype_based_fl/frameworks/FPL/requirements.txt (line 7)) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/prototype_based_fl/frameworks/FPL/requirements.txt (line 8)) (1.16.3)
# Requirement already satisfied: scikit-learn>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/prototype_based_fl/frameworks/FPL/requirements.txt (line 9)) (1.6.1)
# Requirement already satisfied: tqdm>=4.60.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/prototype_based_fl/frameworks/FPL/requirements.txt (line 10)) (4.67.3)
# Collecting setproctitle>=1.2.0 (from -r /content/prototype_based_fl/frameworks/FPL/requirements.txt (line 11))
#   Downloading setproctitle-1.3.7-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/prototype_based_fl/frameworks/FPL/requirements.txt (line 12)) (11.3.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r /content/prototype_based_fl/frameworks/FPL/requirements.txt (line 5)) (3.29.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r /content/prototype_based_fl/frameworks/FPL/requirements.txt (line 5)) (4.15.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r /content/prototype_based_fl/frameworks/FPL/requirements.txt (line 5)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r /content/prototype_based_fl/frameworks/FPL/requirements.txt (line 5)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r /content/prototype_based_fl/frameworks/FPL/requirements.txt (line 5)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r /content/prototype_based_fl/frameworks/FPL/requirements.txt (line 5)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r /content/prototype_based_fl/frameworks/FPL/requirements.txt (line 5)) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.10.0->-r /content/prototype_based_fl/frameworks/FPL/requirements.txt (line 5)) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r /content/prototype_based_fl/frameworks/FPL/requirements.txt (line 5)) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r /content/prototype_based_fl/frameworks/FPL/requirements.txt (line 5)) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r /content/prototype_based_fl/frameworks/FPL/requirements.txt (line 5)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r /content/prototype_based_fl/frameworks/FPL/requirements.txt (line 5)) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r /content/prototype_based_fl/frameworks/FPL/requirements.txt (line 5)) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r /content/prototype_based_fl/frameworks/FPL/requirements.txt (line 5)) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.10.0->-r /content/prototype_based_fl/frameworks/FPL/requirements.txt (line 5)) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.10.0->-r /content/prototype_based_fl/frameworks/FPL/requirements.txt (line 5)) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.10.0->-r /content/prototype_based_fl/frameworks/FPL/requirements.txt (line 5)) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.10.0->-r /content/prototype_based_fl/frameworks/FPL/requirements.txt (line 5)) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.10.0->-r /content/prototype_based_fl/frameworks/FPL/requirements.txt (line 5)) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.10.0->-r /content/prototype_based_fl/frameworks/FPL/requirements.txt (line 5)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.10.0->-r /content/prototype_based_fl/frameworks/FPL/requirements.txt (line 5)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.10.0->-r /content/prototype_based_fl/frameworks/FPL/requirements.txt (line 5)) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.10.0->-r /content/prototype_based_fl/frameworks/FPL/requirements.txt (line 5)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.10.0->-r /content/prototype_based_fl/frameworks/FPL/requirements.txt (line 5)) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.10.0->-r /content/prototype_based_fl/frameworks/FPL/requirements.txt (line 5)) (12.8.90)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.24.0->-r /content/prototype_based_fl/frameworks/FPL/requirements.txt (line 9)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.24.0->-r /content/prototype_based_fl/frameworks/FPL/requirements.txt (line 9)) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=1.10.0->-r /content/prototype_based_fl/frameworks/FPL/requirements.txt (line 5)) (1.5.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.10.0->-r /content/prototype_based_fl/frameworks/FPL/requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.10.0->-r /content/prototype_based_fl/frameworks/FPL/requirements.txt (line 5)) (3.0.3)
# Downloading setproctitle-1.3.7-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (32 kB)
# Installing collected packages: setproctitle
# Successfully installed setproctitle-1.3.7
# 2026-06-29 20:39:25,581 | INFO | [FPL] Dependencies installed successfully.
# 2026-06-29 20:39:25,581 | INFO | --- Running FPL ---
# 2026-06-29 20:39:25,581 | INFO | CWD: /content/prototype_based_fl/frameworks/FPL
# 2026-06-29 20:39:25,581 | INFO | CMD: /usr/bin/python3 /content/prototype_based_fl/frameworks/FPL/main.py --model fpl --dataset fl_digits --parti_num 10 --communication_epoch 20 --local_epoch 10 --seed 42 --device_id 0
# 2026-06-29 20:39:25,581 | INFO | ENV (benchmark): DATA_ROOT=/content/prototype_based_fl/shared_datasets
# fpl_10_fl_digits_20_10
# {np.str_('mnist'): 10}
# ['mnist' 'mnist' 'mnist' 'mnist' 'mnist' 'mnist' 'mnist' 'mnist' 'mnist'
#  'mnist']
# 100% 9.91M/9.91M [00:01<00:00, 5.48MB/s]
# 100% 28.9k/28.9k [00:00<00:00, 133kB/s]
# 100% 1.65M/1.65M [00:01<00:00, 1.23MB/s]
# 100% 4.54k/4.54k [00:00<00:00, 15.6MB/s]
# Local Pariticipant 6 CE = 0.067,InfoNCE = 0.000: 100% 10/10 [00:35<00:00,  3.56s/it]
# Local Pariticipant 4 CE = 0.051,InfoNCE = 0.000: 100% 10/10 [00:34<00:00,  3.41s/it]
# Local Pariticipant 9 CE = 0.040,InfoNCE = 0.000: 100% 10/10 [00:34<00:00,  3.43s/it]
# Local Pariticipant 5 CE = 0.023,InfoNCE = 0.000: 100% 10/10 [00:34<00:00,  3.44s/it]
# Local Pariticipant 3 CE = 0.080,InfoNCE = 0.000: 100% 10/10 [00:36<00:00,  3.60s/it]
# Local Pariticipant 0 CE = 0.045,InfoNCE = 0.000: 100% 10/10 [00:36<00:00,  3.69s/it]
# Local Pariticipant 1 CE = 0.039,InfoNCE = 0.000: 100% 10/10 [00:36<00:00,  3.63s/it]
# Local Pariticipant 8 CE = 0.088,InfoNCE = 0.000: 100% 10/10 [00:34<00:00,  3.50s/it]
# Local Pariticipant 2 CE = 0.057,InfoNCE = 0.000: 100% 10/10 [00:34<00:00,  3.49s/it]
# Local Pariticipant 7 CE = 0.018,InfoNCE = 0.000: 100% 10/10 [00:34<00:00,  3.50s/it]
# Partition 0: 2 clusters
# Partition 0: 1 clusters
# Partition 0: 3 clusters
# Partition 0: 1 clusters
# Partition 0: 2 clusters
# Partition 0: 2 clusters
# Partition 0: 2 clusters
# Partition 0: 1 clusters
# Partition 0: 3 clusters
# Partition 0: 3 clusters
# The 0 Communcation Accuracy: 13.52 Method: fpl
# [13.52]
# Local Pariticipant 9 CE = 0.005,InfoNCE = 0.037: 100% 10/10 [02:18<00:00, 13.88s/it]
# Local Pariticipant 2 CE = 0.019,InfoNCE = 0.053: 100% 10/10 [02:19<00:00, 13.93s/it]
# Local Pariticipant 6 CE = 0.019,InfoNCE = 0.053: 100% 10/10 [02:19<00:00, 13.90s/it]
# Local Pariticipant 4 CE = 0.163,InfoNCE = 0.177: 100% 10/10 [02:18<00:00, 13.89s/it]
# Local Pariticipant 8 CE = 0.084,InfoNCE = 0.089: 100% 10/10 [02:20<00:00, 14.02s/it]
# Local Pariticipant 5 CE = 0.020,InfoNCE = 0.065: 100% 10/10 [02:20<00:00, 14.07s/it]
# Local Pariticipant 7 CE = 0.039,InfoNCE = 0.075: 100% 10/10 [02:20<00:00, 14.04s/it]
# Local Pariticipant 1 CE = 0.020,InfoNCE = 0.051: 100% 10/10 [02:21<00:00, 14.11s/it]
# Local Pariticipant 3 CE = 0.105,InfoNCE = 0.133: 100% 10/10 [02:18<00:00, 13.86s/it]
# Local Pariticipant 0 CE = 0.064,InfoNCE = 0.106: 100% 10/10 [02:23<00:00, 14.37s/it]
# Partition 0: 2 clusters
# Partition 0: 3 clusters
# Partition 0: 2 clusters
# Partition 0: 2 clusters
# Partition 0: 1 clusters
# Partition 0: 2 clusters
# Partition 0: 2 clusters
# Partition 0: 2 clusters
# Partition 0: 2 clusters
# Partition 0: 3 clusters
# The 1 Communcation Accuracy: 97.86 Method: fpl
# [97.86]
# Local Pariticipant 2 CE = 0.009,InfoNCE = 0.038: 100% 10/10 [02:23<00:00, 14.35s/it]
# Local Pariticipant 9 CE = 0.011,InfoNCE = 0.036: 100% 10/10 [02:21<00:00, 14.19s/it]
# Local Pariticipant 1 CE = 0.015,InfoNCE = 0.049: 100% 10/10 [02:22<00:00, 14.21s/it]
# Local Pariticipant 4 CE = 0.074,InfoNCE = 0.082: 100% 10/10 [02:21<00:00, 14.19s/it]
# Local Pariticipant 5 CE = 0.013,InfoNCE = 0.044: 100% 10/10 [02:22<00:00, 14.20s/it]
# Local Pariticipant 0 CE = 0.016,InfoNCE = 0.050: 100% 10/10 [02:21<00:00, 14.16s/it]
# Local Pariticipant 6 CE = 0.030,InfoNCE = 0.050: 100% 10/10 [02:21<00:00, 14.15s/it]
# Local Pariticipant 8 CE = 0.019,InfoNCE = 0.063: 100% 10/10 [02:21<00:00, 14.11s/it]
# Local Pariticipant 7 CE = 0.056,InfoNCE = 0.090: 100% 10/10 [02:22<00:00, 14.21s/it]
# Local Pariticipant 3 CE = 0.055,InfoNCE = 0.111: 100% 10/10 [02:21<00:00, 14.12s/it]
# Partition 0: 2 clusters
# Partition 0: 3 clusters
# Partition 0: 1 clusters
# Partition 0: 2 clusters
# Partition 0: 2 clusters
# Partition 0: 2 clusters
# Partition 0: 3 clusters
# Partition 0: 2 clusters
# Partition 0: 2 clusters
# Partition 0: 2 clusters
# The 2 Communcation Accuracy: 98.8 Method: fpl
# [98.8]
# Local Pariticipant 6 CE = 0.014,InfoNCE = 0.035: 100% 10/10 [02:20<00:00, 14.09s/it]
# Local Pariticipant 3 CE = 0.036,InfoNCE = 0.067: 100% 10/10 [02:21<00:00, 14.11s/it]
# Local Pariticipant 2 CE = 0.010,InfoNCE = 0.036:  40% 4/10 [00:56<01:24, 14.08s/it]

# %%
# !python main_runner.py --framework FedNH --install-deps
# Out:
# 2026-07-01 11:16:59,613 | INFO | Experiment: mnist_prototype_fl_benchmark
# 2026-07-01 11:16:59,613 | INFO | Config: /content/prototype_based_fl/central_config.yaml
# 2026-07-01 11:16:59,613 | INFO | Frameworks: FedNH
# 2026-07-01 11:16:59,613 | INFO | [FedNH] Installing dependencies from /content/prototype_based_fl/frameworks/FedNH/requirements.txt ...
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from -r /content/prototype_based_fl/frameworks/FedNH/requirements.txt (line 1)) (2.11.0+cu128)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from -r /content/prototype_based_fl/frameworks/FedNH/requirements.txt (line 2)) (0.26.0+cu128)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r /content/prototype_based_fl/frameworks/FedNH/requirements.txt (line 3)) (2.0.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from -r /content/prototype_based_fl/frameworks/FedNH/requirements.txt (line 4)) (6.0.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from -r /content/prototype_based_fl/frameworks/FedNH/requirements.txt (line 5)) (3.10.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from -r /content/prototype_based_fl/frameworks/FedNH/requirements.txt (line 6)) (4.67.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/frameworks/FedNH/requirements.txt (line 1)) (3.29.4)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/frameworks/FedNH/requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/frameworks/FedNH/requirements.txt (line 1)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/frameworks/FedNH/requirements.txt (line 1)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/frameworks/FedNH/requirements.txt (line 1)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/frameworks/FedNH/requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/frameworks/FedNH/requirements.txt (line 1)) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/frameworks/FedNH/requirements.txt (line 1)) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/frameworks/FedNH/requirements.txt (line 1)) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/frameworks/FedNH/requirements.txt (line 1)) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/frameworks/FedNH/requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/frameworks/FedNH/requirements.txt (line 1)) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/frameworks/FedNH/requirements.txt (line 1)) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/frameworks/FedNH/requirements.txt (line 1)) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/frameworks/FedNH/requirements.txt (line 1)) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/frameworks/FedNH/requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/frameworks/FedNH/requirements.txt (line 1)) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/frameworks/FedNH/requirements.txt (line 1)) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/frameworks/FedNH/requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/frameworks/FedNH/requirements.txt (line 1)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/frameworks/FedNH/requirements.txt (line 1)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/frameworks/FedNH/requirements.txt (line 1)) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/frameworks/FedNH/requirements.txt (line 1)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/frameworks/FedNH/requirements.txt (line 1)) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/frameworks/FedNH/requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision->-r /content/prototype_based_fl/frameworks/FedNH/requirements.txt (line 2)) (11.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r /content/prototype_based_fl/frameworks/FedNH/requirements.txt (line 5)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r /content/prototype_based_fl/frameworks/FedNH/requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r /content/prototype_based_fl/frameworks/FedNH/requirements.txt (line 5)) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r /content/prototype_based_fl/frameworks/FedNH/requirements.txt (line 5)) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r /content/prototype_based_fl/frameworks/FedNH/requirements.txt (line 5)) (26.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r /content/prototype_based_fl/frameworks/FedNH/requirements.txt (line 5)) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r /content/prototype_based_fl/frameworks/FedNH/requirements.txt (line 5)) (2.9.0.post0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch->-r /content/prototype_based_fl/frameworks/FedNH/requirements.txt (line 1)) (1.5.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->-r /content/prototype_based_fl/frameworks/FedNH/requirements.txt (line 5)) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->-r /content/prototype_based_fl/frameworks/FedNH/requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->-r /content/prototype_based_fl/frameworks/FedNH/requirements.txt (line 1)) (3.0.3)
# 2026-07-01 11:17:02,986 | INFO | [FedNH] Dependencies installed successfully.
# 2026-07-01 11:17:02,986 | INFO | --- Running FedNH ---
# 2026-07-01 11:17:02,987 | INFO | CWD: /content/prototype_based_fl/frameworks/FedNH
# 2026-07-01 11:17:02,987 | INFO | CMD: /usr/bin/python3 /content/prototype_based_fl/frameworks/FedNH/main.py --yamlfile base_config.yaml --strategy FedNH --partition noniid-label-distribution --beta 0.5 --participate_ratio 1.0 --no_norm True --use_wandb False --device cpu --num_clients 10 --num_rounds 20 --num_epochs 10 --client_lr 0.01 --global_seed 42
# 2026-07-01 11:17:02,987 | INFO | ENV (benchmark): DATA_ROOT=/content/prototype_based_fl/shared_datasets
# results are saved in:  ./experiments_FedNH/FedNH_Mnist_ResNet10Mod_noniid-label-distribution_beta:0.5_num_clients:10_participate_ratio:1.0_global_seed:42_FedNH_smoothing:0.9_FedNH_client_adv_prototype_agg:False_no_norm:True
# 100% 9.91M/9.91M [00:01<00:00, 5.69MB/s]
# 100% 28.9k/28.9k [00:00<00:00, 134kB/s]
# 100% 1.65M/1.65M [00:01<00:00, 1.26MB/s]
# 100% 4.54k/4.54k [00:00<00:00, 13.7MB/s]
# ============================================================Run Summary============================================================
# Dataset:
#  dataset:Mnist | num_classes:10 | partition:noniid-label-distribution | beta:0.5
# Server Info:
#  strategy:FedNH | num_clients:10 | num_rounds: 20 | participate_ratio:1.0 | drop_ratio:0.0
# Clients Info:
#  model:ResNet10Mod | num_epochs:5 | batch_size:64 | optimizer:SGD | inint lr:0.01 | lr scheduler:stepwise | momentum: 0.0 | weight decay: 1e-05
#  ResNet10Mod: size:19.592 MB | num params: 4.898 M
# FedUHServer: the following layers will not be updated: ['prototype']
# Strategy Related Hyper-parameters:
#  server side
#   FedNH_smoothing : 0.9
#   FedNH_server_adv_prototype_agg : False
#  client side
#   FedNH_return_embedding : False
#   FedNH_head_init : orthogonal
#   FedNH_client_adv_prototype_agg : False
#   FedNH_fix_scaling : False
# Round:1 - Active clients:[3 9 6 8 2 5 1 7 0 4]:
#  Training time:1049.056 seconds
#  server global model correct 7492
#  Testing time:128.996 seconds
#  avg_test_acc: {'uniform': 0.7491999864578247, 'validclass': 0.7491999864578247, 'labeldist': 0.7544623017311096}
#  pfl_avg_test_acc: {'uniform': 0.5683599948883057, 'validclass': 0.6566804647445679, 'labeldist': 0.8930453658103943}
# Round:2 - Active clients:[2 7 9 0 6 8 5 1 3 4]:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/subprocess.py", line 1264, in wait
#     return self._wait(timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/subprocess.py", line 2053, in _wait
#     (pid, sts) = self._try_wait(0)
#                  ^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/subprocess.py", line 2011, in _try_wait
#     (pid, sts) = os.waitpid(self.pid, wait_flags)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/prototype_based_fl/main_runner.py", line 743, in <module>
#     raise SystemExit(main())
#                      ^^^^^^
#   File "/content/prototype_based_fl/main_runner.py", line 734, in main
#     return run_benchmark(
#            ^^^^^^^^^^^^^^
#   File "/content/prototype_based_fl/main_runner.py", line 667, in run_benchmark
#     code = run_subprocess(
#            ^^^^^^^^^^^^^^^
#   File "/content/prototype_based_fl/main_runner.py", line 572, in run_subprocess
#     completed = subprocess.run(
#                 ^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/subprocess.py", line 550, in run
#     stdout, stderr = process.communicate(input, timeout=timeout)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/subprocess.py", line 1201, in communicate
#     self.wait()
#   File "/usr/lib/python3.12/subprocess.py", line 1277, in wait
#     self._wait(timeout=sigint_timeout)
#   File "/usr/lib/python3.12/subprocess.py", line 2047, in _wait
#     time.sleep(delay)
# KeyboardInterrupt
# ^C

# %% [markdown]
# ### Optional: Download your results
# Run the cell below if you want to zip and download your `results/` folder to your computer after training finishes.

# %%
# !zip -r results.zip results/
# from google.colab import files
# files.download('results.zip')
