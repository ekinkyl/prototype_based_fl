# %% [markdown]
# # Run Prototype-based FL on Colab
# This notebook clones your GitHub repository, sets the hardware to `cuda`, and runs the FPL framework using your A100/T4 GPU.

# %%
# 1. Clone the repository
# !git clone https://github.com/ekinkyl/prototype_based_fl
# %cd prototype_based_fl
# Out:
# Cloning into 'prototype_based_fl'...
# remote: Enumerating objects: 415, done.
# remote: Counting objects: 100% (415/415), done.
# remote: Compressing objects: 100% (308/308), done.
# remote: Total 415 (delta 179), reused 304 (delta 88), pack-reused 0 (from 0)
# Receiving objects: 100% (415/415), 31.26 MiB | 20.73 MiB/s, done.
# Resolving deltas: 100% (179/179), done.
# /content/prototype_based_fl

# %%
# 2. Modify the central_config.yaml to use 'cuda' instead of 'cpu'
import yaml

with open('central_config.yaml', 'r') as f:
    config = yaml.safe_load(f)

config['runtime']['device'] = 'cuda'

with open('central_config.yaml', 'w') as f:
    yaml.dump(config, f)

print("Config updated to use CUDA!")
# Out:
# Config updated to use CUDA!

# %%
# !git pull origin main
# !python main_runner.py --framework FedPall --install-deps
# Out:
# From https://github.com/ekinkyl/prototype_based_fl
#  * branch            main       -> FETCH_HEAD
# Already up to date.
# 2026-07-06 07:13:39,591 | INFO | Experiment: mnist_prototype_fl_benchmark
# 2026-07-06 07:13:39,591 | INFO | Config: /content/prototype_based_fl/central_config.yaml
# 2026-07-06 07:13:39,591 | INFO | Frameworks: FedPall
# 2026-07-06 07:13:39,592 | INFO | [FedPall] Installing dependencies from /content/prototype_based_fl/frameworks/FedPall/requirements.txt ...
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from -r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 1)) (2.11.0+cu128)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from -r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 2)) (0.26.0+cu128)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 3)) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from -r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 4)) (2.2.2)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (from -r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 5)) (0.13.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from -r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 6)) (4.67.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from -r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 7)) (1.6.1)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.12/dist-packages (from -r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 8)) (3.1.5)
# Collecting tensorboardX (from -r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 9))
#   Downloading tensorboardx-2.6.5-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from -r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 10)) (5.12.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 1)) (3.29.4)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 1)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 1)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 1)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 1)) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 1)) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 1)) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 1)) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 1)) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 1)) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 1)) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 1)) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 1)) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 1)) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 1)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 1)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 1)) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 1)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 1)) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 2)) (11.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 4)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 4)) (2026.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.12/dist-packages (from seaborn->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 5)) (3.10.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 7)) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 7)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 7)) (3.6.0)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 8)) (2.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorboardX->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 9)) (26.2)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.12/dist-packages (from tensorboardX->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 9)) (5.29.6)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from transformers->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 10)) (1.20.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 10)) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 10)) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 10)) (0.22.2)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from transformers->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 10)) (0.25.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 10)) (0.8.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 1)) (1.5.5)
# Requirement already satisfied: click>=8.4.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 10)) (8.4.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 10)) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 10)) (0.28.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 5)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 5)) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 5)) (1.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 5)) (3.3.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 4)) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 10)) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 10)) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->transformers->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 10)) (0.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 10)) (4.14.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 10)) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 10)) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 10)) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 10)) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 10)) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 10)) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers->-r /content/prototype_based_fl/frameworks/FedPall/requirements.txt (line 10)) (0.1.2)
# Downloading tensorboardx-2.6.5-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 3.4 MB/s eta 0:00:00
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.6.5
# 2026-07-06 07:13:44,332 | INFO | [FedPall] Dependencies installed successfully.
# 2026-07-06 07:13:44,333 | INFO | [FedPall] Running data generation script...
# Generating MNIST: niid=True, balance=True, partition=dir, alpha=0.1, num_clients=10
# 100% 9.91M/9.91M [00:00<00:00, 52.4MB/s]
# 100% 28.9k/28.9k [00:00<00:00, 1.56MB/s]
# 100% 1.65M/1.65M [00:00<00:00, 14.7MB/s]
# 100% 4.54k/4.54k [00:00<00:00, 18.8MB/s]
# Saved 10 clients to /content/prototype_based_fl/frameworks/FedPall/data/MNIST/partitions and test.pkl
# 2026-07-06 07:14:01,808 | INFO | --- Running FedPall ---
# 2026-07-06 07:14:01,808 | INFO | CWD: /content/prototype_based_fl/frameworks/FedPall/exps
# 2026-07-06 07:14:01,808 | INFO | CMD: /usr/bin/python3 /content/prototype_based_fl/frameworks/FedPall/exps/federated_main.py --exp 1 --mode ours --dataset fl_digits --num_users 10 --iters 20 --wk_iters 10 --batch 64 --lr 0.01 --seed 42
# 2026-07-06 07:14:01,808 | INFO | ENV (benchmark): DATA_ROOT=/content/prototype_based_fl/shared_datasets
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# Namespace(exp=1, iters=20, wk_iters=5, batch=64, lr=0.01, number_workers=4, size=28, mode='ours', dataset='fl_digits', optimizer='sgd', num_users=10, features=1, labels=0, num_classes=10, save_path='../result/exp1/fl_digits/resnet/', device='cuda:0', seed=1, momentum=1, loss_component=1, cls_component=1, mix_mode=1, percent=0.1, adcol_epoch=1, uniform_left=0.8, uniform_right=0.2, adcol_mu=0.7, adcol_beta=0.3, feat_loss_arg=0.1, crt_feat_num=50, ld=1, mu=0.01, alpha=1, T=3.0, beta=0.01, tau=1, times=1.0, lamb=100, std_coeff=2.5, unif_coeff=0.5)
#   0% 0/20 [00:00<?, ?it/s]
#  | Global Training Round : 0 |
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:432: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
#
# MNIST       | train loss: 0.0246 | kl loss : 0.0010| Test Acc: 0.3291
#   5% 1/20 [03:50<1:13:04, 230.74s/it]
#  | Global Training Round : 1 |
#
#
# MNIST       | train loss: 0.0070 | kl loss : 0.2667| Test Acc: 0.3459
#  10% 2/20 [07:44<1:09:48, 232.68s/it]
#  | Global Training Round : 2 |
#
#
# MNIST       | train loss: 0.0051 | kl loss : 0.2444| Test Acc: 0.3495
#  15% 3/20 [11:38<1:06:02, 233.11s/it]
#  | Global Training Round : 3 |
#
#
# MNIST       | train loss: 0.0044 | kl loss : 0.2320| Test Acc: 0.3521
#  20% 4/20 [15:32<1:02:14, 233.40s/it]
#  | Global Training Round : 4 |
#
#
# MNIST       | train loss: 0.0040 | kl loss : 0.2250| Test Acc: 0.3542
#  25% 5/20 [19:25<58:20, 233.33s/it]
#  | Global Training Round : 5 |
#
#
# MNIST       | train loss: 0.0038 | kl loss : 0.2205| Test Acc: 0.3562
#  30% 6/20 [23:20<54:35, 233.95s/it]
#  | Global Training Round : 6 |
#
#
# MNIST       | train loss: 0.0036 | kl loss : 0.2176| Test Acc: 0.3579
#  35% 7/20 [27:15<50:44, 234.22s/it]
#  | Global Training Round : 7 |
#
#
# MNIST       | train loss: 0.0034 | kl loss : 0.2159| Test Acc: 0.3590
#  40% 8/20 [31:09<46:52, 234.33s/it]
#  | Global Training Round : 8 |
#
#
# MNIST       | train loss: 0.0033 | kl loss : 0.2148| Test Acc: 0.3603
#  45% 9/20 [35:03<42:55, 234.10s/it]
#  | Global Training Round : 9 |
#
#
# MNIST       | train loss: 0.0032 | kl loss : 0.2139| Test Acc: 0.3615
#  50% 10/20 [38:56<38:58, 233.84s/it]
#  | Global Training Round : 10 |
#
#
# MNIST       | train loss: 0.0031 | kl loss : 0.2133| Test Acc: 0.3626
#  55% 11/20 [42:48<35:00, 233.34s/it]
#  | Global Training Round : 11 |
#
#
# MNIST       | train loss: 0.0030 | kl loss : 0.2136| Test Acc: 0.3637
#  60% 12/20 [46:42<31:07, 233.46s/it]
#  | Global Training Round : 12 |
#
#
# MNIST       | train loss: 0.0029 | kl loss : 0.2142| Test Acc: 0.3646
#  65% 13/20 [50:35<27:13, 233.40s/it]
#  | Global Training Round : 13 |
#
#
# MNIST       | train loss: 0.0028 | kl loss : 0.2155| Test Acc: 0.3654
#  70% 14/20 [54:28<23:19, 233.27s/it]
#  | Global Training Round : 14 |
#
#
# MNIST       | train loss: 0.0028 | kl loss : 0.2172| Test Acc: 0.3664
#  75% 15/20 [58:20<19:24, 232.84s/it]
#  | Global Training Round : 15 |
#
#
# MNIST       | train loss: 0.0027 | kl loss : 0.2193| Test Acc: 0.3672
#  80% 16/20 [1:02:11<15:28, 232.23s/it]
#  | Global Training Round : 16 |
#
#
# MNIST       | train loss: 0.0027 | kl loss : 0.2216| Test Acc: 0.3680
#  85% 17/20 [1:06:02<11:35, 231.88s/it]
#  | Global Training Round : 17 |
#
#
# MNIST       | train loss: 0.0026 | kl loss : 0.2241| Test Acc: 0.3688
#  90% 18/20 [1:09:54<07:43, 231.81s/it]
#  | Global Training Round : 18 |
#
#
# MNIST       | train loss: 0.0026 | kl loss : 0.2266| Test Acc: 0.3695
#  95% 19/20 [1:13:46<03:51, 231.94s/it]
#  | Global Training Round : 19 |
#
#
# MNIST       | train loss: 0.0025 | kl loss : 0.2294| Test Acc: 0.3700
# 100% 20/20 [1:17:38<00:00, 232.94s/it]
# 2026-07-06 08:32:13,456 | INFO | FedPall completed successfully.
