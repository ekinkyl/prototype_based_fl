# %% [markdown]
# # Run Prototype-based FL on Colab
# This notebook clones your GitHub repository, sets the hardware to `cuda`, and runs the FPL framework using your A100/T4 GPU.

# %%
# 1. Clone the repository
# !git clone https://github.com/ekinkyl/prototype_based_fl
# %cd prototype_based_fl
# Out:
# fatal: destination path 'prototype_based_fl' already exists and is not an empty directory.
# /content/prototype_based_fl/prototype_based_fl

# %%
# 2. Modify the central_config.yaml to use 'cuda' instead of 'cpu'
import yaml

with open('central_config.yaml', 'r') as f:
    config = yaml.safe_load(f)

config['runtime']['device'] = 'cuda'

with open('central_config.yaml', 'w') as f:
    yaml.dump(config, f)

print("Config updated to use CUDA!")
# Out:
# Config updated to use CUDA!

# %%
# !git pull origin main
# !python main_runner.py --framework FedTGP --install-deps
# Out:
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 8 (delta 5), reused 8 (delta 5), pack-reused 0 (from 0)
# Unpacking objects: 100% (8/8), 696 bytes | 348.00 KiB/s, done.
# From https://github.com/ekinkyl/prototype_based_fl
#  * branch            main       -> FETCH_HEAD
#    0f59e88..a25a1df  main       -> origin/main
# Updating 0f59e88..a25a1df
# Fast-forward
#  frameworks/FedTGP/system/flcore/clients/clientbase.py | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)
# 2026-07-02 11:52:43,672 | INFO | Experiment: mnist_prototype_fl_benchmark
# 2026-07-02 11:52:43,673 | INFO | Config: /content/prototype_based_fl/prototype_based_fl/central_config.yaml
# 2026-07-02 11:52:43,673 | INFO | Frameworks: FedTGP
# 2026-07-02 11:52:43,673 | INFO | [FedTGP] Installing dependencies from /content/prototype_based_fl/prototype_based_fl/frameworks/FedTGP/requirements.txt ...
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from -r /content/prototype_based_fl/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (2.11.0+cu128)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from -r /content/prototype_based_fl/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 2)) (0.26.0+cu128)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r /content/prototype_based_fl/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 3)) (2.0.2)
# Requirement already satisfied: calmsize in /usr/local/lib/python3.12/dist-packages (from -r /content/prototype_based_fl/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 4)) (0.1.3)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from -r /content/prototype_based_fl/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 5)) (3.16.0)
# Requirement already satisfied: ujson in /usr/local/lib/python3.12/dist-packages (from -r /content/prototype_based_fl/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 6)) (5.13.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from -r /content/prototype_based_fl/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 7)) (1.6.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (3.29.4)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/prototype_based_fl/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r /content/prototype_based_fl/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision->-r /content/prototype_based_fl/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 2)) (11.3.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r /content/prototype_based_fl/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 7)) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r /content/prototype_based_fl/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 7)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r /content/prototype_based_fl/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 7)) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch->-r /content/prototype_based_fl/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (1.5.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->-r /content/prototype_based_fl/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->-r /content/prototype_based_fl/prototype_based_fl/frameworks/FedTGP/requirements.txt (line 1)) (3.0.3)
# 2026-07-02 11:52:46,354 | INFO | [FedTGP] Dependencies installed successfully.
# 2026-07-02 11:52:46,355 | INFO | --- Running FedTGP ---
# 2026-07-02 11:52:46,355 | INFO | CWD: /content/prototype_based_fl/prototype_based_fl/frameworks/FedTGP/system
# 2026-07-02 11:52:46,355 | INFO | CMD: /usr/bin/python3 /content/prototype_based_fl/prototype_based_fl/frameworks/FedTGP/system/main.py -data mnist -m HtFE3_MNIST -algo FedTGP -go test -nc 10 -gr 20 -ls 10 -lbs 64 -lr 0.01
# 2026-07-02 11:52:46,355 | INFO | ENV (benchmark): DATA_ROOT=/content/prototype_based_fl/prototype_based_fl/shared_datasets
# ==================================================
# Algorithm: FedTGP
# Local batch size: 64
# Local steps: 10
# Local learing rate: 0.01
# Total number of clients: 10
# Clients join in each round: 1.0
# Clients randomly join: False
# Client drop rate: 0.0
# Client select regarding time: False
# Running times: 1
# Dataset: mnist
# Number of classes: 10
# Backbone: HtFE3_MNIST
# Using device: cuda
# Auto break: False
# Global rounds: 20
# ==================================================
#
# ============= Running time: 0th =============
# Creating server and clients ...
# resnet10(in_channels=1, num_classes=args.num_classes)
# resnet18(in_channels=1, num_classes=args.num_classes)
# resnet34(in_channels=1, num_classes=args.num_classes)
#
# Join ratio / total clients: 1.0 / 10
# Finished creating server and clients.
# Trainable_Global_Prototypes(
#   (embedings): Embedding(10, 512)
#   (middle): Sequential(
#     (0): Sequential(
#       (0): Linear(in_features=512, out_features=512, bias=True)
#       (1): ReLU()
#     )
#   )
#   (fc): Linear(in_features=512, out_features=512, bias=True)
# )
#
# -------------Round number: 0-------------
#
# Evaluate heterogeneous models
# Server global_protos Not Found
# Client 0: Acc: 0.0, AUC: 0
# Server global_protos Not Found
# Client 1: Acc: 0.0, AUC: 0
# Server global_protos Not Found
# Client 2: Acc: 0.0, AUC: 0
# Server global_protos Not Found
# Client 3: Acc: 0.0, AUC: 0
# Server global_protos Not Found
# Client 4: Acc: 0.0, AUC: 0
# Server global_protos Not Found
# Client 5: Acc: 0.0, AUC: 0
# Server global_protos Not Found
# Client 6: Acc: 0.0, AUC: 0
# Server global_protos Not Found
# Client 7: Acc: 0.0, AUC: 0
# Server global_protos Not Found
# Client 8: Acc: 0.0, AUC: 0
# Server global_protos Not Found
# Client 9: Acc: 0.0, AUC: 0
# Averaged Test Accurancy: 0.0000
# Averaged Test AUC: 0.0000
# Std Test Accurancy: 0.0000
# Std Test AUC: 0.0000
# Server global_protos Not Found
# Server global_protos Not Found
# Server global_protos Not Found
# Server global_protos Not Found
# Server global_protos Not Found
# Server global_protos Not Found
# Server global_protos Not Found
# Server global_protos Not Found
# Server global_protos Not Found
# Server global_protos Not Found
# class-wise minimum distance tensor([ 4.3235,  7.1747,  1.2081, 13.0345,  9.3327,  1.3387,  7.4725,  1.2081,
#          4.3235,  7.1747], device='cuda:0')
# min_gap tensor(1.2081, device='cuda:0')
# max_gap tensor(13.0345, device='cuda:0')
# Server loss: 15.008100509643555
# -------------------------------------------------- 71.7999804019928
#
# -------------Round number: 1-------------
#
# Evaluate heterogeneous models
# Client 0: Acc: 0.256838905775076, AUC: 0
# Client 1: Acc: 0.0, AUC: 0
# Client 2: Acc: 0.007352941176470588, AUC: 0
# Client 3: Acc: 0.006289308176100629, AUC: 0
# Client 4: Acc: 0.027083333333333334, AUC: 0
# Client 5: Acc: 0.10981912144702842, AUC: 0
# Client 6: Acc: 0.6242038216560509, AUC: 0
# Client 7: Acc: 0.012578616352201259, AUC: 0
# Client 8: Acc: 0.8222222222222222, AUC: 0
# Client 9: Acc: 0.37624750499001997, AUC: 0
# Averaged Test Accurancy: 0.2623
# Averaged Test AUC: 0.0000
# Std Test Accurancy: 0.2799
# Std Test AUC: 0.0000
# class-wise minimum distance tensor([2.7908, 3.1146, 2.9573, 3.5321, 3.1925, 3.4758, 2.4508, 3.1146, 2.4508,
#         2.9263], device='cuda:0')
# min_gap tensor(2.4508, device='cuda:0')
# max_gap tensor(3.5321, device='cuda:0')
# Server loss: 3.546698570251465
# -------------------------------------------------- 79.63481068611145
#
# -------------Round number: 2-------------
#
# Evaluate heterogeneous models
# Client 0: Acc: 0.7386018237082067, AUC: 0
# Client 1: Acc: 0.592, AUC: 0
# Client 2: Acc: 0.4534313725490196, AUC: 0
# Client 3: Acc: 0.6194968553459119, AUC: 0
# Client 4: Acc: 0.8666666666666667, AUC: 0
# Client 5: Acc: 0.011627906976744186, AUC: 0
# Client 6: Acc: 0.9012738853503185, AUC: 0
# Client 7: Acc: 0.9182389937106918, AUC: 0
# Client 8: Acc: 0.6811111111111111, AUC: 0
# Client 9: Acc: 0.9650698602794411, AUC: 0
# Averaged Test Accurancy: 0.5835
# Averaged Test AUC: 0.0000
# Std Test Accurancy: 0.2710
# Std Test AUC: 0.0000
# class-wise minimum distance tensor([3.1677, 2.5526, 3.1788, 3.3805, 3.5335, 3.5859, 3.1176, 2.5526, 3.1176,
#         3.2965], device='cuda:0')
# min_gap tensor(2.5526, device='cuda:0')
# max_gap tensor(3.5859, device='cuda:0')
# Server loss: 3.2106010913848877
# -------------------------------------------------- 79.55024862289429
#
# -------------Round number: 3-------------
#
# Evaluate heterogeneous models
# Client 0: Acc: 0.9300911854103343, AUC: 0
# Client 1: Acc: 0.784, AUC: 0
# Client 2: Acc: 0.9656862745098039, AUC: 0
# Client 3: Acc: 0.9182389937106918, AUC: 0
# Client 4: Acc: 0.9291666666666667, AUC: 0
# Client 5: Acc: 0.9877260981912145, AUC: 0
# Client 6: Acc: 0.9299363057324841, AUC: 0
# Client 7: Acc: 0.9654088050314465, AUC: 0
# Client 8: Acc: 0.9988888888888889, AUC: 0
# Client 9: Acc: 0.9770459081836327, AUC: 0
# Averaged Test Accurancy: 0.9610
# Averaged Test AUC: 0.0000
# Std Test Accurancy: 0.0579
# Std Test AUC: 0.0000
# class-wise minimum distance tensor([4.7473, 4.6739, 4.6688, 5.5704, 4.2958, 5.7000, 4.6688, 4.2958, 4.9662,
#         5.6815], device='cuda:0')
# min_gap tensor(4.2958, device='cuda:0')
# max_gap tensor(5.7000, device='cuda:0')
# Server loss: 3.7896790504455566
# -------------------------------------------------- 79.83599424362183
#
# -------------Round number: 4-------------
#
# Evaluate heterogeneous models
# Client 0: Acc: 0.9513677811550152, AUC: 0
# Client 1: Acc: 0.808, AUC: 0
# Client 2: Acc: 0.9828431372549019, AUC: 0
# Client 3: Acc: 0.9889937106918238, AUC: 0
# Client 4: Acc: 0.9416666666666667, AUC: 0
# Client 5: Acc: 0.9870801033591732, AUC: 0
# Client 6: Acc: 0.9426751592356688, AUC: 0
# Client 7: Acc: 0.9622641509433962, AUC: 0
# Client 8: Acc: 0.9988888888888889, AUC: 0
# Client 9: Acc: 0.9760479041916168, AUC: 0
# Averaged Test Accurancy: 0.9729
# Averaged Test AUC: 0.0000
# Std Test Accurancy: 0.0523
# Std Test AUC: 0.0000
# class-wise minimum distance tensor([5.7141, 5.4640, 5.7141, 6.9649, 4.9032, 6.9849, 5.8776, 4.9032, 6.0798,
#         6.8887], device='cuda:0')
# min_gap tensor(4.9032, device='cuda:0')
# max_gap tensor(6.9849, device='cuda:0')
# Server loss: 4.1336164474487305
# -------------------------------------------------- 79.79521942138672
#
# -------------Round number: 5-------------
#
# Evaluate heterogeneous models
# Client 0: Acc: 0.952887537993921, AUC: 0
# Client 1: Acc: 0.816, AUC: 0
# Client 2: Acc: 0.9852941176470589, AUC: 0
# Client 3: Acc: 0.9905660377358491, AUC: 0
# Client 4: Acc: 0.94375, AUC: 0
# Client 5: Acc: 0.9896640826873385, AUC: 0
# Client 6: Acc: 0.9363057324840764, AUC: 0
# Client 7: Acc: 0.9654088050314465, AUC: 0
# Client 8: Acc: 0.9988888888888889, AUC: 0
# Client 9: Acc: 0.9760479041916168, AUC: 0
# Averaged Test Accurancy: 0.9742
# Averaged Test AUC: 0.0000
# Std Test Accurancy: 0.0507
# Std Test AUC: 0.0000
# class-wise minimum distance tensor([6.5663, 6.6652, 6.5663, 8.3377, 5.5081, 8.0004, 6.9863, 5.5081, 7.0337,
#         8.0264], device='cuda:0')
# min_gap tensor(5.5081, device='cuda:0')
# max_gap tensor(8.3377, device='cuda:0')
# Server loss: 4.613453388214111
# -------------------------------------------------- 79.60980463027954
#
# -------------Round number: 6-------------
#
# Evaluate heterogeneous models
# Client 0: Acc: 0.952887537993921, AUC: 0
# Client 1: Acc: 0.824, AUC: 0
# Client 2: Acc: 0.9877450980392157, AUC: 0
# Client 3: Acc: 0.9937106918238994, AUC: 0
# Client 4: Acc: 0.9520833333333333, AUC: 0
# Client 5: Acc: 0.9909560723514211, AUC: 0
# Client 6: Acc: 0.9394904458598726, AUC: 0
# Client 7: Acc: 0.9622641509433962, AUC: 0
# Client 8: Acc: 0.9988888888888889, AUC: 0
# Client 9: Acc: 0.9760479041916168, AUC: 0
# Averaged Test Accurancy: 0.9757
# Averaged Test AUC: 0.0000
# Std Test Accurancy: 0.0486
# Std Test AUC: 0.0000
# class-wise minimum distance tensor([7.3670, 7.5173, 7.3670, 8.9958, 6.0434, 8.8219, 7.9052, 6.0434, 7.6119,
#         8.9661], device='cuda:0')
# min_gap tensor(6.0434, device='cuda:0')
# max_gap tensor(8.9958, device='cuda:0')
# Server loss: 4.637120723724365
# -------------------------------------------------- 79.91748762130737
#
# -------------Round number: 7-------------
#
# Evaluate heterogeneous models
# Client 0: Acc: 0.9544072948328267, AUC: 0
# Client 1: Acc: 0.816, AUC: 0
# Client 2: Acc: 0.9901960784313726, AUC: 0
# Client 3: Acc: 0.9968553459119497, AUC: 0
# Client 4: Acc: 0.95625, AUC: 0
# Client 5: Acc: 0.9922480620155039, AUC: 0
# Client 6: Acc: 0.9363057324840764, AUC: 0
# Client 7: Acc: 0.9654088050314465, AUC: 0
# Client 8: Acc: 0.9988888888888889, AUC: 0
# Client 9: Acc: 0.9760479041916168, AUC: 0
# Averaged Test Accurancy: 0.9768
# Averaged Test AUC: 0.0000
# Std Test Accurancy: 0.0514
# Std Test AUC: 0.0000
# class-wise minimum distance tensor([8.1378, 8.3202, 8.1378, 9.4929, 6.5486, 9.5354, 8.6589, 6.5486, 8.1763,
#         9.8887], device='cuda:0')
# min_gap tensor(6.5486, device='cuda:0')
# max_gap tensor(9.8887, device='cuda:0')
# Server loss: 4.898638725280762
# -------------------------------------------------- 79.95212316513062
#
# -------------Round number: 8-------------
#
# Evaluate heterogeneous models
# Client 0: Acc: 0.952887537993921, AUC: 0
# Client 1: Acc: 0.848, AUC: 0
# Client 2: Acc: 0.9901960784313726, AUC: 0
# Client 3: Acc: 0.9984276729559748, AUC: 0
# Client 4: Acc: 0.9583333333333334, AUC: 0
# Client 5: Acc: 0.9922480620155039, AUC: 0
# Client 6: Acc: 0.9394904458598726, AUC: 0
# Client 7: Acc: 0.9685534591194969, AUC: 0
# Client 8: Acc: 0.9988888888888889, AUC: 0
# Client 9: Acc: 0.9770459081836327, AUC: 0
# Averaged Test Accurancy: 0.9781
# Averaged Test AUC: 0.0000
# Std Test Accurancy: 0.0427
# Std Test AUC: 0.0000
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/subprocess.py", line 1264, in wait
#     return self._wait(timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/subprocess.py", line 2053, in _wait
#     (pid, sts) = self._try_wait(0)
#                  ^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/subprocess.py", line 2011, in _try_wait
#     (pid, sts) = os.waitpid(self.pid, wait_flags)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/prototype_based_fl/prototype_based_fl/main_runner.py", line 770, in <module>
#     raise SystemExit(main())
#                      ^^^^^^
#   File "/content/prototype_based_fl/prototype_based_fl/main_runner.py", line 761, in main
#     return run_benchmark(
#            ^^^^^^^^^^^^^^
#   File "/content/prototype_based_fl/prototype_based_fl/main_runner.py", line 694, in run_benchmark
#     code = run_subprocess(
#            ^^^^^^^^^^^^^^^
#   File "/content/prototype_based_fl/prototype_based_fl/main_runner.py", line 599, in run_subprocess
#     completed = subprocess.run(
#                 ^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/subprocess.py", line 550, in run
#     stdout, stderr = process.communicate(input, timeout=timeout)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/subprocess.py", line 1201, in communicate
#     self.wait()
#   File "/usr/lib/python3.12/subprocess.py", line 1277, in wait
#     self._wait(timeout=sigint_timeout)
#   File "/usr/lib/python3.12/subprocess.py", line 2036, in _wait
#     (pid, sts) = self._try_wait(os.WNOHANG)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/subprocess.py", line 2008, in _try_wait
#     def _try_wait(self, wait_flags):
#
# KeyboardInterrupt
# ^C

# %% [markdown]
# ### Optional: Download your results
# Run the cell below if you want to zip and download your `results/` folder to your computer after training finishes.

# %%
# !zip -r results.zip results/
# from google.colab import files
# files.download('results.zip')
