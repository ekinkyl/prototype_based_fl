# %% [markdown]
# # Run Prototype-based FL on Colab
# This notebook clones your GitHub repository, sets the hardware to `cuda`, and runs the FPL framework using your A100/T4 GPU.

# %%
# 1. Clone the repository
# !git clone https://github.com/ekinkyl/prototype_based_fl
# %cd prototype_based_fl
# Out:
# Cloning into 'prototype_based_fl'...
# remote: Enumerating objects: 340, done.
# remote: Counting objects: 100% (340/340), done.
# remote: Compressing objects: 100% (247/247), done.
# remote: Total 340 (delta 140), reused 265 (delta 78), pack-reused 0 (from 0)
# Receiving objects: 100% (340/340), 31.16 MiB | 19.75 MiB/s, done.
# Resolving deltas: 100% (140/140), done.
# /content/prototype_based_fl

# %%
# 2. Modify the central_config.yaml to use 'cuda' instead of 'cpu'
import yaml

with open('central_config.yaml', 'r') as f:
    config = yaml.safe_load(f)

config['runtime']['device'] = 'cuda'

with open('central_config.yaml', 'w') as f:
    yaml.dump(config, f)

print("Config updated to use CUDA!")
# Out:
# Config updated to use CUDA!

# %%
# !git pull origin main
# !python main_runner.py --framework FedDAP --install-deps
# Out:
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 7 (delta 5), reused 7 (delta 5), pack-reused 0 (from 0)
# Unpacking objects: 100% (7/7), 632 bytes | 316.00 KiB/s, done.
# From https://github.com/ekinkyl/prototype_based_fl
#  * branch            main       -> FETCH_HEAD
#    74171b1..bfd8b54  main       -> origin/main
# Updating 74171b1..bfd8b54
# Fast-forward
#  frameworks/FedDAP/datasets/utils/federated_dataset.py | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)
# 2026-07-02 22:32:27,211 | INFO | Experiment: mnist_prototype_fl_benchmark
# 2026-07-02 22:32:27,211 | INFO | Config: /content/prototype_based_fl/central_config.yaml
# 2026-07-02 22:32:27,211 | INFO | Frameworks: FedDAP
# 2026-07-02 22:32:27,211 | INFO | [FedDAP] Installing dependencies from /content/prototype_based_fl/frameworks/FedDAP/requirements.txt ...
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.12/dist-packages (from -r /content/prototype_based_fl/frameworks/FedDAP/requirements.txt (line 1)) (1.3.7)
# 2026-07-02 22:32:29,625 | INFO | [FedDAP] Dependencies installed successfully.
# 2026-07-02 22:32:29,626 | INFO | --- Running FedDAP ---
# 2026-07-02 22:32:29,626 | INFO | CWD: /content/prototype_based_fl/frameworks/FedDAP
# 2026-07-02 22:32:29,626 | INFO | CMD: /usr/bin/python3 /content/prototype_based_fl/frameworks/FedDAP/main.py --model feddap --dataset fl_digits --parti_num 10 --communication_epoch 20 --local_epoch 10 --seed 42
# 2026-07-02 22:32:29,626 | INFO | ENV (benchmark): DATA_ROOT=/content/prototype_based_fl/shared_datasets
# feddap_10_fl_digits_20_10
#  Running Domain Skew Setting
# {np.str_('mnist'): 10}
# ['mnist' 'mnist' 'mnist' 'mnist' 'mnist' 'mnist' 'mnist' 'mnist' 'mnist'
#  'mnist']
# mean: 6000.0
# std: 916.3265793373016
# Data statistics: {0: {np.int64(0): np.int64(67), np.int64(1): np.int64(27), np.int64(2): np.int64(1128), np.int64(3): np.int64(128), np.int64(4): np.int64(1859), np.int64(5): np.int64(314), np.int64(6): np.int64(549), np.int64(7): np.int64(492), np.int64(8): np.int64(421), np.int64(9): np.int64(456)}, 1: {np.int64(0): np.int64(252), np.int64(1): np.int64(103), np.int64(2): np.int64(486), np.int64(3): np.int64(446), np.int64(4): np.int64(97), np.int64(5): np.int64(657), np.int64(6): np.int64(741), np.int64(7): np.int64(1946), np.int64(8): np.int64(631), np.int64(9): np.int64(120)}, 2: {np.int64(0): np.int64(445), np.int64(1): np.int64(638), np.int64(2): np.int64(827), np.int64(3): np.int64(974), np.int64(4): np.int64(43), np.int64(5): np.int64(432), np.int64(6): np.int64(262), np.int64(7): np.int64(11), np.int64(8): np.int64(53), np.int64(9): np.int64(908)}, 3: {np.int64(0): np.int64(367), np.int64(1): np.int64(2792), np.int64(2): np.int64(104), np.int64(3): np.int64(409), np.int64(4): np.int64(378), np.int64(5): np.int64(448), np.int64(6): np.int64(395), np.int64(7): np.int64(671), np.int64(8): np.int64(1171)}, 4: {np.int64(0): np.int64(706), np.int64(1): np.int64(211), np.int64(2): np.int64(1082), np.int64(3): np.int64(123), np.int64(4): np.int64(1542), np.int64(5): np.int64(58), np.int64(6): np.int64(169), np.int64(7): np.int64(1041), np.int64(8): np.int64(264), np.int64(9): np.int64(656)}, 5: {np.int64(0): np.int64(371), np.int64(1): np.int64(1027), np.int64(2): np.int64(16), np.int64(3): np.int64(1121), np.int64(4): np.int64(192), np.int64(5): np.int64(976), np.int64(6): np.int64(114), np.int64(7): np.int64(220), np.int64(8): np.int64(1108), np.int64(9): np.int64(458)}, 6: {np.int64(0): np.int64(449), np.int64(1): np.int64(461), np.int64(2): np.int64(135), np.int64(3): np.int64(1292), np.int64(4): np.int64(89), np.int64(5): np.int64(269), np.int64(6): np.int64(553), np.int64(7): np.int64(293), np.int64(8): np.int64(72), np.int64(9): np.int64(1331)}, 7: {np.int64(0): np.int64(1333), np.int64(1): np.int64(374), np.int64(2): np.int64(198), np.int64(3): np.int64(357), np.int64(4): np.int64(655), np.int64(5): np.int64(492), np.int64(6): np.int64(1657), np.int64(7): np.int64(294), np.int64(8): np.int64(1957)}, 8: {np.int64(0): np.int64(684), np.int64(1): np.int64(1015), np.int64(2): np.int64(404), np.int64(3): np.int64(261), np.int64(4): np.int64(966), np.int64(5): np.int64(1206), np.int64(6): np.int64(117), np.int64(7): np.int64(481), np.int64(8): np.int64(173), np.int64(9): np.int64(2020)}, 9: {np.int64(0): np.int64(1249), np.int64(1): np.int64(94), np.int64(2): np.int64(1578), np.int64(3): np.int64(1020), np.int64(4): np.int64(21), np.int64(5): np.int64(569), np.int64(6): np.int64(1361), np.int64(7): np.int64(816), np.int64(8): np.int64(1)}}
# [6, 2, 4, 8, 3, 1, 9, 0, 7, 5]
# Local Pariticipant 6 CE = 0.128,InfoNCE = 0.000: 100% 10/10 [00:13<00:00,  1.35s/it]
# Local Pariticipant 2 CE = 0.305,InfoNCE = 0.000: 100% 10/10 [00:11<00:00,  1.17s/it]
# Local Pariticipant 4 CE = 0.154,InfoNCE = 0.000: 100% 10/10 [00:14<00:00,  1.44s/it]
# Local Pariticipant 8 CE = 0.015,InfoNCE = 0.000: 100% 10/10 [00:17<00:00,  1.73s/it]
# Local Pariticipant 3 CE = 0.024,InfoNCE = 0.000: 100% 10/10 [00:16<00:00,  1.64s/it]
# Local Pariticipant 1 CE = 0.051,InfoNCE = 0.000: 100% 10/10 [00:13<00:00,  1.38s/it]
# Local Pariticipant 9 CE = 0.033,InfoNCE = 0.000: 100% 10/10 [00:16<00:00,  1.66s/it]
# Local Pariticipant 0 CE = 0.210,InfoNCE = 0.000: 100% 10/10 [00:14<00:00,  1.40s/it]
# Local Pariticipant 7 CE = 0.084,InfoNCE = 0.000: 100% 10/10 [00:18<00:00,  1.81s/it]
# Local Pariticipant 5 CE = 0.050,InfoNCE = 0.000: 100% 10/10 [00:14<00:00,  1.42s/it]
# The 0 Communcation Accuracy: 11.39 Method: feddap
# [11.39]
# [5, 3, 1, 2, 4, 8, 7, 0, 6, 9]
# Local Pariticipant 5 CE = 0.014,InfoNCE = 0.000: 100% 10/10 [00:22<00:00,  2.25s/it]
# Local Pariticipant 3 CE = 0.035,InfoNCE = 0.000: 100% 10/10 [00:26<00:00,  2.69s/it]
# Local Pariticipant 1 CE = 0.135,InfoNCE = 0.000: 100% 10/10 [00:22<00:00,  2.25s/it]
# Local Pariticipant 2 CE = 0.016,InfoNCE = 0.000: 100% 10/10 [00:18<00:00,  1.87s/it]
# Local Pariticipant 4 CE = 0.021,InfoNCE = 0.000: 100% 10/10 [00:23<00:00,  2.36s/it]
# Local Pariticipant 8 CE = 0.015,InfoNCE = 0.000: 100% 10/10 [00:29<00:00,  2.93s/it]
# Local Pariticipant 7 CE = 0.004,InfoNCE = 0.000: 100% 10/10 [00:29<00:00,  2.98s/it]
# Local Pariticipant 0 CE = 0.050,InfoNCE = 0.000: 100% 10/10 [00:21<00:00,  2.19s/it]
# Local Pariticipant 6 CE = 0.003,InfoNCE = 0.000: 100% 10/10 [00:20<00:00,  2.02s/it]
# Local Pariticipant 9 CE = 0.017,InfoNCE = 0.000: 100% 10/10 [00:26<00:00,  2.69s/it]
# The 1 Communcation Accuracy: 95.12 Method: feddap
# [95.12]
# [6, 8, 4, 7, 1, 9, 5, 2, 0, 3]
# Local Pariticipant 6 CE = 0.017,InfoNCE = 0.000: 100% 10/10 [00:20<00:00,  2.01s/it]
# Local Pariticipant 8 CE = 0.004,InfoNCE = 0.000: 100% 10/10 [00:29<00:00,  2.97s/it]
# Local Pariticipant 4 CE = 0.003,InfoNCE = 0.000:  10% 1/10 [00:02<00:20,  2.32s/it]Traceback (most recent call last):
#   File "/usr/lib/python3.12/subprocess.py", line 1264, in wait
#     return self._wait(timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/subprocess.py", line 2053, in _wait
#     (pid, sts) = self._try_wait(0)
#                  ^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/subprocess.py", line 2011, in _try_wait
#     (pid, sts) = os.waitpid(self.pid, wait_flags)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/prototype_based_fl/main_runner.py", line 806, in <module>
#     raise SystemExit(main())
#                      ^^^^^^
#   File "/content/prototype_based_fl/main_runner.py", line 797, in main
#     return run_benchmark(
#            ^^^^^^^^^^^^^^
#   File "/content/prototype_based_fl/main_runner.py", line 730, in run_benchmark
#     code = run_subprocess(
#            ^^^^^^^^^^^^^^^
#   File "/content/prototype_based_fl/main_runner.py", line 635, in run_subprocess
#     completed = subprocess.run(
#                 ^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/subprocess.py", line 550, in run
#     stdout, stderr = process.communicate(input, timeout=timeout)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/subprocess.py", line 1201, in communicate
#     self.wait()
#   File "/usr/lib/python3.12/subprocess.py", line 1277, in wait
#     self._wait(timeout=sigint_timeout)
#   File "/usr/lib/python3.12/subprocess.py", line 2021, in _wait
#     def _wait(self, timeout):
#
# KeyboardInterrupt
# ^C

# %% [markdown]
# ### Optional: Download your results
# Run the cell below if you want to zip and download your `results/` folder to your computer after training finishes.

# %%
# !zip -r results.zip results/
# from google.colab import files
# files.download('results.zip')
